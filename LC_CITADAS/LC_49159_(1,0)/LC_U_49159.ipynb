# %%
# %matplotlib inline
import carmcmc as cm
import numpy as np
import matplotlib.pyplot as plt


sigmay = 2.3 
p = 5 
mu = 17.0  
qpo_width = np.array([1.0/100.0, 1.0/300.0, 1.0/200.0]) 
qpo_cent = np.array([1.0/5.0, 1.0/25.0]) 
ar_roots = cm.get_ar_roots(qpo_width, qpo_cent) 
ar_coefs = np.poly(ar_roots)
ma_coefs = np.array([1.0, 4.5, 1.25, 0.0, 0.0])
sigsqr = sigmay ** 2 / cm.carma_variance(1.0, ar_roots, ma_coefs=ma_coefs)

# %%
data = np.genfromtxt('LC_U_49159.dat')
juldate = data[:,0]  
t = juldate - juldate.min()  
y = data[:,1]  
yerr = data[:,2]  

plt.errorbar(t, y, yerr=yerr)
plt.plot(t, y, 'k.')
plt.xlim(t.min(), t.max())
plt.xlabel('Tiempo [dias]')
plt.ylabel('Magnitud')
# Out:
# Text(0,0.5,'Magnitud')

# %%
model = cm.CarmaModel(t, y, yerr, p=1, q=0)

# %%
# %%capture capt
sample = model.run_mcmc(20000)

# %%
sample.assess_fit()

# %%
psd_low, psd_hi, psd_mid, frequencies = sample.plot_power_spectrum(percentile=95.0, nsamples=5000)

# %%
plt.loglog(frequencies, psd_mid)
plt.fill_between(frequencies, psd_hi, y2=psd_low, alpha=0.5)
plt.loglog(frequencies, np.ones(frequencies.size) * noise_level, color='grey', lw=2)
plt.ylim(noise_level / 10.0, plt.ylim()[1])
plt.xlim(frequencies.min(), frequencies[psd_hi > noise_level].max() * 10.0)
plt.ylabel('Espectro de potencia')
plt.xlabel('Frecuencia  [1 / dia]')
plt.annotate("Nivel de ruido", (1.25* plt.xlim()[0], noise_level / 1.5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-196ff3ec4753> in <module>()
#       1 plt.loglog(frequencies, psd_mid)
#       2 plt.fill_between(frequencies, psd_hi, y2=psd_low, alpha=0.5)
# ----> 3 plt.loglog(frequencies, np.ones(frequencies.size) * noise_level, color='grey', lw=2)
#       4 plt.ylim(noise_level / 10.0, plt.ylim()[1])
#       5 plt.xlim(frequencies.min(), frequencies[psd_hi > noise_level].max() * 10.0)
#
# NameError: name 'noise_level' is not defined

# %%
tpredict = t.max() + np.linspace(0.0, 250.0, 250)
ypredict, yp_var = sample.predict(tpredict)
plt.errorbar(t, y, yerr=yerr, color='black')
plt.plot(t, y, 'ko', ms=4)
plt.fill_between(tpredict, ypredict+np.sqrt(yp_var), y2=ypredict-np.sqrt(yp_var), color='DodgerBlue', alpha=0.5)
plt.plot(tpredict, ypredict, 'b-')
plt.xlim(tpredict.min() - 100, tpredict.max())
plt.xlabel('Tiempo [dias]')
plt.ylabel('Magnitud')
plt.title('Prediccion , valor esperado ')
# Out:
# Text(0.5,1,'Prediccion , valor esperado ')

# %%
tpredict = t.max() + np.linspace(0.0, 200.0, 250)
npaths = 3
plt.errorbar(t, y, yerr=yerr, color='black')
plt.plot(t, y, 'ko', ms=4)
for i in range(npaths):
    ysim = sample.simulate(tpredict, bestfit='random')  
    plt.plot(tpredict, ysim)
plt.xlabel('Tiempo [dias]')
plt.ylabel('Magnitude')
plt.xlim(tpredict.min()-100, tpredict.max())
plt.title('Prediccion, Caminos simulados')
# Out:
# Text(0.5,1,'Prediccion, Caminos simulados')

# %%
tpredict = 10.0
nsim = 10000
ysim = np.zeros(nsim)
for i in range(nsim):
    ysim[i] = sample.simulate(tpredict, bestfit='random')
yhat, yhvar = sample.predict(tpredict)
plt.hist(ysim, bins=100, alpha=0.5, histtype='stepfilled', normed=True, label='Incertidumbre ')
ymin, ymax = plt.xlim()
ygrid = np.linspace(ymin, ymax, 200)
predictive_pdf = 1.0 / np.sqrt(2.0 * np.pi * yhvar) * np.exp(-0.5 * (ygrid - yhat) ** 2 / yhvar)
plt.plot(ygrid, predictive_pdf, color='DarkOrange', lw=2, label='Mejor ajuste ')
plt.xlim(ymin, ymax + 0.1 * (ymax - ymin))
plt.legend(loc='upper right')
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
tinterp = t.max() - 1000 + np.linspace(0.0, 1000.0, 500)
ypredict, yp_var = sample.predict(tinterp)
plt.errorbar(t, y, yerr=yerr, color='black')
plt.plot(t, y, 'ko', ms=4)
plt.fill_between(tinterp, ypredict+np.sqrt(yp_var), y2=ypredict-np.sqrt(yp_var), color='DodgerBlue', alpha=0.5)
plt.plot(tinterp, ypredict, 'b-')
plt.xlabel('tiempo [dias]')
plt.ylabel('magnitud')
plt.xlim(tinterp.min(), tinterp.max())
plt.title('Interpolacion, camino simulado')
# Out:
# Text(0.5,1,'Interpolacion, camino simulado')

# %%
tinterp = t.max() - 1000 + np.linspace(0.0, 1000.0, 500)
npaths = 6
for i in range(npaths):
    ysim = sample.simulate(tinterp, bestfit='random')
    plt.plot(tinterp, ysim)
plt.plot(t, y, 'ko', ms=4)
plt.xlabel('Tiempo  [dias]')
plt.ylabel('magnitud')
plt.xlim(tinterp.min(), tinterp.max())
plt.title('Interpolacion, camino simulado')
# Out:
# Text(0.5,1,'Interpolacion, camino simulado')

# %%
sample.parameters
# Out:
# ['logpost', 'mu', 'log_omega', 'loglik', 'var', 'measerr_scale', 'sigma']

# %%
centroid_samples = sample.get_samples('logpost')
centroid_samples.shape
# Out:
# (20000, 1)

# %%
sample.posterior_summaries('logpost')
# Out:
# Calculating effective number of samples
# Posterior summary for parameter logpost  element 0
# ----------------------------------------------
# Effective number of independent samples: 736.457786102
# Median: 66.848311529
# Standard deviation: 1.4241316147
# 68% credibility interval: [ 65.35380991  68.08921987]
# 95% credibility interval: [ 63.41306844  68.84674074]
# 99% credibility interval: [ 61.64839698  69.09752394]

# %%
centroid_samples = sample.get_samples('mu')
centroid_samples.shape
# Out:
# (20000, 1)

# %%
sample.posterior_summaries('mu')
# Out:
# Calculating effective number of samples
# Posterior summary for parameter mu  element 0
# ----------------------------------------------
# Effective number of independent samples: 514.635224834
# Median: 20.1426545156
# Standard deviation: 0.237604024671
# 68% credibility interval: [ 19.94783851  20.31401352]
# 95% credibility interval: [ 19.58515474  20.61067395]
# 99% credibility interval: [ 19.17843345  20.82896778]

# %%
centroid_samples = sample.get_samples('loglik')
centroid_samples.shape
# Out:
# (20000, 1)

# %%
sample.posterior_summaries('loglik')
# Out:
# Calculating effective number of samples
# Posterior summary for parameter loglik  element 0
# ----------------------------------------------
# Effective number of independent samples: 671.475432873
# Median: 92.1270078979
# Standard deviation: 1.26517817914
# 68% credibility interval: [ 90.87040568  93.30051781]
# 95% credibility interval: [ 89.07780963  93.92841695]
# 99% credibility interval: [ 87.50195601  94.13204315]

# %%
centroid_samples = sample.get_samples('var')
centroid_samples.shape
# Out:
# (20000, 1)

# %%
sample.posterior_summaries('var')
# Out:
# Calculating effective number of samples
# Posterior summary for parameter var  element 0
# ----------------------------------------------
# Effective number of independent samples: 492.434342046
# Median: 0.089885119021
# Standard deviation: 0.107653612937
# 68% credibility interval: [ 0.04019768  0.22315076]
# 95% credibility interval: [ 0.02278771  0.41796238]
# 99% credibility interval: [ 0.0167084   0.55895609]

# %%
centroid_samples = sample.get_samples('measerr_scale')
centroid_samples.shape
# Out:
# (20000, 1)

# %%
sample.posterior_summaries('measerr_scale')
# Out:
# Calculating effective number of samples
# Posterior summary for parameter measerr_scale  element 0
# ----------------------------------------------
# Effective number of independent samples: 1083.02161806
# Median: 0.965149716689
# Standard deviation: 0.162809461472
# 68% credibility interval: [ 0.82865159  1.13798534]
# 95% credibility interval: [ 0.71206278  1.35602111]
# 99% credibility interval: [ 0.64622712  1.52250231]

# %%
centroid_samples = sample.get_samples('sigma')
centroid_samples.shape
# Out:
# (20000, 1)

# %%
sample.posterior_summaries('sigma')
# Out:
# Calculating effective number of samples
# Posterior summary for parameter sigma  element 0
# ----------------------------------------------
# Effective number of independent samples: 1031.31515645
# Median: 0.014973899003
# Standard deviation: 0.0038917709322
# 68% credibility interval: [ 0.01184874  0.01904996]
# 95% credibility interval: [ 0.00952225  0.02487675]
# 99% credibility interval: [ 0.00848595  0.02949504]

# %%
sample.plot_2dkde('mu', 'measerr_scale', doShow=True)
# Out:
# Plotting 2d PDF w KDE

# %%
sample.plot_2dpdf('mu', 'measerr_scale', doShow=True)
# Out:
# Plotting 2d PDF
